# %%
import pandas as pd

def clean_futures(df):
    """
    Clean NIFTY Futures data:
    - Fill missing values
    - Convert timestamps
    - Handle rollover if needed
    """
    df.fillna(method='ffill', inplace=True)
    df['timestamp'] = pd.to_datetime(df['timestamp'])
    return df
